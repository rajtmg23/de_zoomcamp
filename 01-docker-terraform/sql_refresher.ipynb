# %% [markdown]
# #### For running the sql queries on jupyter notebook we are gonna use the [`ipython-sql`](https://github.com/catherinedevlin/ipython-sql) module.
#
# ``` python
# pip install ipython-sql
# pip install psycopg2-binary
# ```
# ##### Load the extension with the command `%load_ext`

# %%
# pip install ipython-sql
# %load_ext sql

# %% [markdown]
# #### For creating a connection we are using the following syntax for postgres.
# ``` postgresql://user:password@host:port/db_name```

# %%
# %sql postgresql://root:root@localhost:5432/ny_taxi

# %sql postgresql://

# %% [markdown]
# For this session we are going to use to tables of the database:
#
# 1. [`yellow_taxi_trips`](https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-01.csv) : This table contains the list of information about the trips done by the yellow taxi in nyc.
# 2. `taxi_zones` : This table contains the information about the zones details where the tips has been made.

# %% [markdown]
# ** `%sql` will consider only the single line as a query whereas `%%sql` will take all the cell value as sql query.**

# %%
# Starting with the simple sql query
# %sql SELECT * FROM yellow_taxi_trips LIMIT 5;
# Out:
#  * postgresql://root:***@localhost:5432/ny_taxi
# 5 rows affected.
# [(1, datetime.datetime(2021, 1, 1, 0, 30, 10), datetime.datetime(2021, 1, 1, 0, 36, 12), 1, 2.1, 1, 'N', 142, 43, 2, 8.0, 3.0, 0.5, 0.0, 0.0, 0.3, 11.8, 2.5),
#  (1, datetime.datetime(2021, 1, 1, 0, 51, 20), datetime.datetime(2021, 1, 1, 0, 52, 19), 1, 0.2, 1, 'N', 238, 151, 2, 3.0, 0.5, 0.5, 0.0, 0.0, 0.3, 4.3, 0.0),
#  (1, datetime.datetime(2021, 1, 1, 0, 43, 30), datetime.datetime(2021, 1, 1, 1, 11, 6), 1, 14.7, 1, 'N', 132, 165, 1, 42.0, 0.5, 0.5, 8.65, 0.0, 0.3, 51.95, 0.0),
#  (1, datetime.datetime(2021, 1, 1, 0, 15, 48), datetime.datetime(2021, 1, 1, 0, 31, 1), 0, 10.6, 1, 'N', 138, 132, 1, 29.0, 0.5, 0.5, 6.05, 0.0, 0.3, 36.35, 0.0),
#  (2, datetime.datetime(2021, 1, 1, 0, 31, 49), datetime.datetime(2021, 1, 1, 0, 48, 21), 1, 4.94, 1, 'N', 68, 33, 1, 16.5, 0.5, 0.5, 4.06, 0.0, 0.3, 24.36, 2.5)]

# %%
# %sql SELECT * FROM taxi_zones LIMIT 5;
# Out:
#  * postgresql://root:***@localhost:5432/ny_taxi
# 5 rows affected.
# [(1, 'EWR', 'Newark Airport', 'EWR'),
#  (2, 'Queens', 'Jamaica Bay', 'Boro Zone'),
#  (3, 'Bronx', 'Allerton/Pelham Gardens', 'Boro Zone'),
#  (4, 'Manhattan', 'Alphabet City', 'Yellow Zone'),
#  (5, 'Staten Island', 'Arden Heights', 'Boro Zone')]

# %% [markdown]
# ### Exploring the database tables and data.

# %%
# %%sql
# SELECT *
# FROM
#     yellow_taxi_trips yt JOIN taxi_zones tz
#     ON yt."PULocationID" = tz."LocationID"
# WHERE
#     yt."PULocationID" = tz."LocationID"
# LIMIT 5;
# Out:
#  * postgresql://root:***@localhost:5432/ny_taxi
# 5 rows affected.
# [(1, datetime.datetime(2021, 1, 1, 0, 30, 10), datetime.datetime(2021, 1, 1, 0, 36, 12), 1, 2.1, 1, 'N', 142, 43, 2, 8.0, 3.0, 0.5, 0.0, 0.0, 0.3, 11.8, 2.5, 142, 'Manhattan', 'Lincoln Square East', 'Yellow Zone'),
#  (1, datetime.datetime(2021, 1, 1, 0, 51, 20), datetime.datetime(2021, 1, 1, 0, 52, 19), 1, 0.2, 1, 'N', 238, 151, 2, 3.0, 0.5, 0.5, 0.0, 0.0, 0.3, 4.3, 0.0, 238, 'Manhattan', 'Upper West Side North', 'Yellow Zone'),
#  (1, datetime.datetime(2021, 1, 1, 0, 43, 30), datetime.datetime(2021, 1, 1, 1, 11, 6), 1, 14.7, 1, 'N', 132, 165, 1, 42.0, 0.5, 0.5, 8.65, 0.0, 0.3, 51.95, 0.0, 132, 'Queens', 'JFK Airport', 'Airports'),
#  (1, datetime.datetime(2021, 1, 1, 0, 15, 48), datetime.datetime(2021, 1, 1, 0, 31, 1), 0, 10.6, 1, 'N', 138, 132, 1, 29.0, 0.5, 0.5, 6.05, 0.0, 0.3, 36.35, 0.0, 138, 'Queens', 'LaGuardia Airport', 'Airports'),
#  (2, datetime.datetime(2021, 1, 1, 0, 31, 49), datetime.datetime(2021, 1, 1, 0, 48, 21), 1, 4.94, 1, 'N', 68, 33, 1, 16.5, 0.5, 0.5, 4.06, 0.0, 0.3, 24.36, 2.5, 68, 'Manhattan', 'East Chelsea', 'Yellow Zone')]

# %% [markdown]
# #### Selects all columns from the yellow_taxi_trips table. Select only the first 5 rows.

# %%
# %%sql
# SELECT
#     *
# FROM
#     yellow_taxi_trips t,
#     taxi_zones zpu,
#     taxi_zones zdo
# WHERE
#     t."PULocationID" = zpu."LocationID" AND
#     t."DOLocationID" = zdo."LocationID"
# LIMIT 5;
# Out:
#  * postgresql://root:***@localhost:5432/ny_taxi
# 5 rows affected.
# [(1, datetime.datetime(2021, 1, 1, 0, 30, 10), datetime.datetime(2021, 1, 1, 0, 36, 12), 1, 2.1, 1, 'N', 142, 43, 2, 8.0, 3.0, 0.5, 0.0, 0.0, 0.3, 11.8, 2.5, 142, 'Manhattan', 'Lincoln Square East', 'Yellow Zone', 43, 'Manhattan', 'Central Park', 'Yellow Zone'),
#  (1, datetime.datetime(2021, 1, 1, 0, 51, 20), datetime.datetime(2021, 1, 1, 0, 52, 19), 1, 0.2, 1, 'N', 238, 151, 2, 3.0, 0.5, 0.5, 0.0, 0.0, 0.3, 4.3, 0.0, 238, 'Manhattan', 'Upper West Side North', 'Yellow Zone', 151, 'Manhattan', 'Manhattan Valley', 'Yellow Zone'),
#  (1, datetime.datetime(2021, 1, 1, 0, 43, 30), datetime.datetime(2021, 1, 1, 1, 11, 6), 1, 14.7, 1, 'N', 132, 165, 1, 42.0, 0.5, 0.5, 8.65, 0.0, 0.3, 51.95, 0.0, 132, 'Queens', 'JFK Airport', 'Airports', 165, 'Brooklyn', 'Midwood', 'Boro Zone'),
#  (1, datetime.datetime(2021, 1, 1, 0, 15, 48), datetime.datetime(2021, 1, 1, 0, 31, 1), 0, 10.6, 1, 'N', 138, 132, 1, 29.0, 0.5, 0.5, 6.05, 0.0, 0.3, 36.35, 0.0, 138, 'Queens', 'LaGuardia Airport', 'Airports', 132, 'Queens', 'JFK Airport', 'Airports'),
#  (2, datetime.datetime(2021, 1, 1, 0, 31, 49), datetime.datetime(2021, 1, 1, 0, 48, 21), 1, 4.94, 1, 'N', 68, 33, 1, 16.5, 0.5, 0.5, 4.06, 0.0, 0.3, 24.36, 2.5, 68, 'Manhattan', 'East Chelsea', 'Yellow Zone', 33, 'Brooklyn', 'Brooklyn Heights', 'Boro Zone')]

# %% [markdown]
# * We give aliases to the `yellow_taxi_trips` and `taxi_zones' tables for easier access.
# * We replace the IDs inside `PULocationID` and `DOLocationID` with the actual zone IDs for pick ups and drop offs.
# * We use double quotes (`""`) for the column names because in Postgres we need to use them if the column names contains capital letters.

# %%
# %%sql
# SELECT
#     tpep_pickup_datetime,
#     tpep_dropoff_datetime,
#     total_amount,
#     CONCAT(zpu."Borough", '/', zpu."Zone") AS "pickup_loc",
#     CONCAT(zdo."Borough", '/', zdo."Zone") AS "dropoff_loc"
# FROM
#     yellow_taxi_trips t,
#     taxi_zones zpu,
#     taxi_zones zdo
# WHERE
#     t."PULocationID" = zpu."LocationID" AND
#     t."DOLocationID" = zdo."LocationID"
# LIMIT 5;
# Out:
#  * postgresql://root:***@localhost:5432/ny_taxi
# 5 rows affected.
# [(datetime.datetime(2021, 1, 1, 0, 30, 10), datetime.datetime(2021, 1, 1, 0, 36, 12), 11.8, 'Manhattan/Lincoln Square East', 'Manhattan/Central Park'),
#  (datetime.datetime(2021, 1, 1, 0, 51, 20), datetime.datetime(2021, 1, 1, 0, 52, 19), 4.3, 'Manhattan/Upper West Side North', 'Manhattan/Manhattan Valley'),
#  (datetime.datetime(2021, 1, 1, 0, 43, 30), datetime.datetime(2021, 1, 1, 1, 11, 6), 51.95, 'Queens/JFK Airport', 'Brooklyn/Midwood'),
#  (datetime.datetime(2021, 1, 1, 0, 15, 48), datetime.datetime(2021, 1, 1, 0, 31, 1), 36.35, 'Queens/LaGuardia Airport', 'Queens/JFK Airport'),
#  (datetime.datetime(2021, 1, 1, 0, 31, 49), datetime.datetime(2021, 1, 1, 0, 48, 21), 24.36, 'Manhattan/East Chelsea', 'Brooklyn/Brooklyn Heights')]

# %% [markdown]
# * Same as previous but instead of the complete rows we only display specific columns.
# * We make use of joins (implicit joins in this case) to display combined info as a single column.
#     * The new "virtual" column `pickup_loc` contains the values of both `Borough` and `Zone` columns of the zones table, separated by a slash (`/`).
#     * Same for `dropoff_loc`.
# * More specifically this is an inner join, because we only select the rows that overlap between the 2 tables.
# * Learn more about SQL joins [here](https://dataschool.com/how-to-teach-people-sql/sql-join-types-explained-visually/) and [here](https://www.wikiwand.com/en/Join_(SQL)).

# %%
# %%sql
# SELECT
#     tpep_pickup_datetime,
#     tpep_dropoff_datetime,
#     total_amount,
#     CONCAT(zpu."Borough", '/', zpu."Zone") AS "pickup_loc",
#     CONCAT(zdo."Borough", '/', zdo."Zone") AS "dropoff_loc"
# FROM
#     yellow_taxi_trips t JOIN taxi_zones zpu
#         ON t."PULocationID" = zpu."LocationID"
#     JOIN taxi_zones zdo
#         ON t."DOLocationID" = zdo."LocationID"
# LIMIT 5;
# Out:
#  * postgresql://root:***@localhost:5432/ny_taxi
# 5 rows affected.
# [(datetime.datetime(2021, 1, 1, 0, 30, 10), datetime.datetime(2021, 1, 1, 0, 36, 12), 11.8, 'Manhattan/Lincoln Square East', 'Manhattan/Central Park'),
#  (datetime.datetime(2021, 1, 1, 0, 51, 20), datetime.datetime(2021, 1, 1, 0, 52, 19), 4.3, 'Manhattan/Upper West Side North', 'Manhattan/Manhattan Valley'),
#  (datetime.datetime(2021, 1, 1, 0, 43, 30), datetime.datetime(2021, 1, 1, 1, 11, 6), 51.95, 'Queens/JFK Airport', 'Brooklyn/Midwood'),
#  (datetime.datetime(2021, 1, 1, 0, 15, 48), datetime.datetime(2021, 1, 1, 0, 31, 1), 36.35, 'Queens/LaGuardia Airport', 'Queens/JFK Airport'),
#  (datetime.datetime(2021, 1, 1, 0, 31, 49), datetime.datetime(2021, 1, 1, 0, 48, 21), 24.36, 'Manhattan/East Chelsea', 'Brooklyn/Brooklyn Heights')]

# %% [markdown]
# * Exactly the same statement as before but rewritten using explicit `JOIN` keywords.
#     * Explicit inner joins are preferred over implicit inner joins.
# * The `JOIN` keyword is used after the `FROM` statement rather than the `WHERE` statement. The `WHERE` statement is actually unneeded.
#     ```sql
#     SELECT whatever_columns FROM table_1 JOIN table_2_with_a_matching_column ON column_from_1=column_from_2
#     ```
# * You can also use the keyword `INNER JOIN` for clarity.
# * Learn more about SQL joins [here](https://dataschool.com/how-to-teach-people-sql/sql-join-types-explained-visually/) and [here](https://www.wikiwand.com/en/Join_(SQL)).

# %% [markdown]
# ##### Checking whether `PULocationID` column contains null values.

# %%
# %%sql
# SELECT
#     tpep_pickup_datetime,
#     tpep_dropoff_datetime,
#     total_amount,
#     "PULocationID",
#     "DOLocationID"
# FROM
#     yellow_taxi_trips
# WHERE
#     "PULocationID" is NULL
# LIMIT 100;
# Out:
#  * postgresql://root:***@localhost:5432/ny_taxi
# 0 rows affected.
# []

# %% [markdown]
# ##### Checking whether `DOLocationID` column contains null values.

# %%
# %%sql
# SELECT
#     tpep_pickup_datetime,
#     tpep_dropoff_datetime,
#     total_amount,
#     "PULocationID",
#     "DOLocationID"
# FROM
#     yellow_taxi_trips
# WHERE
#     "DOLocationID" is NULL
# LIMIT 100;
# Out:
#  * postgresql://root:***@localhost:5432/ny_taxi
# 0 rows affected.
# []

# %% [markdown]
# * Selects rows fromn the `yellow_taxi_trips` table whose drop off location ID does not appear in the `taxi_zones` table.
# * If you did not modify any rows in the original datasets, the query would return an empty list.

# %%
# %%sql
# SELECT
#     tpep_pickup_datetime,
#     tpep_dropoff_datetime,
#     total_amount,
#     "PULocationID",
#     "DOLocationID"
# FROM
#     yellow_taxi_trips
# WHERE
#     "DOLocationID" NOT IN (
#         SELECT "LocationID" FROM taxi_zones
#     )
# LIMIT 100;
# Out:
#  * postgresql://root:***@localhost:5432/ny_taxi
# 0 rows affected.
# []

# %%
# %%sql
# SELECT
#     tpep_pickup_datetime,
#     tpep_dropoff_datetime,
#     total_amount,
#     "PULocationID",
#     "DOLocationID"
# FROM
#     yellow_taxi_trips
# WHERE
#     "PULocationID" NOT IN (
#         SELECT "LocationID" FROM taxi_zones
#     )
# LIMIT 100;
# Out:
#  * postgresql://root:***@localhost:5432/ny_taxi
# 0 rows affected.
# []

# %% [markdown]
# * Delete records from the `taxi_zones` table where `LocationID` is 142.

# %%
# %%sql
# DELETE FROM taxi_zones WHERE "LocationID" = 142;
# Out:
#  * postgresql://root:***@localhost:5432/ny_taxi
# 1 rows affected.
# []

# %%
# %%sql
# SELECT
#     tpep_pickup_datetime,
#     tpep_dropoff_datetime,
#     total_amount,
#     "PULocationID",
#     "DOLocationID"
# FROM
#     yellow_taxi_trips
# WHERE
#     "PULocationID" NOT IN (
#         SELECT "LocationID" FROM taxi_zones
#     )
# LIMIT 10;
# Out:
#  * postgresql://root:***@localhost:5432/ny_taxi
# 10 rows affected.
# [(datetime.datetime(2021, 1, 1, 0, 30, 10), datetime.datetime(2021, 1, 1, 0, 36, 12), 11.8, 142, 43),
#  (datetime.datetime(2021, 1, 1, 0, 31, 6), datetime.datetime(2021, 1, 1, 0, 38, 52), 14.16, 142, 50),
#  (datetime.datetime(2021, 1, 1, 0, 33, 38), datetime.datetime(2021, 1, 1, 0, 38, 37), 12.09, 142, 239),
#  (datetime.datetime(2021, 1, 1, 0, 57, 26), datetime.datetime(2021, 1, 1, 1, 1, 27), 8.8, 142, 48),
#  (datetime.datetime(2021, 1, 1, 0, 25, 23), datetime.datetime(2021, 1, 1, 0, 31, 57), 12.96, 142, 238),
#  (datetime.datetime(2021, 1, 1, 0, 18, 14), datetime.datetime(2021, 1, 1, 0, 27, 29), 17.8, 142, 229),
#  (datetime.datetime(2021, 1, 1, 0, 2), datetime.datetime(2021, 1, 1, 0, 13, 59), 15.3, 142, 263),
#  (datetime.datetime(2021, 1, 1, 0, 32, 1), datetime.datetime(2021, 1, 1, 0, 44, 55), 20.8, 142, 116),
#  (datetime.datetime(2021, 1, 1, 0, 32, 58), datetime.datetime(2021, 1, 1, 0, 40, 59), 15.8, 142, 75),
#  (datetime.datetime(2021, 1, 1, 0, 15, 41), datetime.datetime(2021, 1, 1, 0, 23, 6), 14.75, 142, 236)]

# %% [markdown]
# #### The below sql statement will only show the records if both the `PULocationID` & `DOLocationID` matches with the `LocationID`.

# %%
# %%sql
# SELECT
#     tpep_pickup_datetime,
#     tpep_dropoff_datetime,
#     total_amount,
#     CONCAT(zpu."Borough", '/', zpu."Zone") AS "pickup_loc",
#     CONCAT(zdo."Borough", '/', zdo."Zone") AS "dropoff_loc"
# FROM
#     yellow_taxi_trips yt JOIN taxi_zones zpu
#         ON yt."PULocationID" = zpu."LocationID"
#     LEFT JOIN taxi_zones zdo
#         ON yt."DOLocationID" = zdo."LocationID"
# LIMIT 10;
# Out:
#  * postgresql://root:***@localhost:5432/ny_taxi
# 10 rows affected.
# [(datetime.datetime(2021, 1, 1, 0, 51, 20), datetime.datetime(2021, 1, 1, 0, 52, 19), 4.3, 'Manhattan/Upper West Side North', 'Manhattan/Manhattan Valley'),
#  (datetime.datetime(2021, 1, 1, 0, 43, 30), datetime.datetime(2021, 1, 1, 1, 11, 6), 51.95, 'Queens/JFK Airport', 'Brooklyn/Midwood'),
#  (datetime.datetime(2021, 1, 1, 0, 15, 48), datetime.datetime(2021, 1, 1, 0, 31, 1), 36.35, 'Queens/LaGuardia Airport', 'Queens/JFK Airport'),
#  (datetime.datetime(2021, 1, 1, 0, 31, 49), datetime.datetime(2021, 1, 1, 0, 48, 21), 24.36, 'Manhattan/East Chelsea', 'Brooklyn/Brooklyn Heights'),
#  (datetime.datetime(2021, 1, 1, 0, 16, 29), datetime.datetime(2021, 1, 1, 0, 24, 30), 14.15, 'Manhattan/Stuy Town/Peter Cooper Village', 'Manhattan/East Chelsea'),
#  (datetime.datetime(2021, 1, 1, 0, 0, 28), datetime.datetime(2021, 1, 1, 0, 17, 28), 17.3, 'Queens/Forest Hills', 'Queens/Maspeth'),
#  (datetime.datetime(2021, 1, 1, 0, 12, 29), datetime.datetime(2021, 1, 1, 0, 30, 34), 21.8, 'Manhattan/Flatiron', 'Brooklyn/Carroll Gardens'),
#  (datetime.datetime(2021, 1, 1, 0, 39, 16), datetime.datetime(2021, 1, 1, 1, 0, 13), 28.8, 'Brooklyn/Fort Greene', 'Queens/Jackson Heights'),
#  (datetime.datetime(2021, 1, 1, 0, 26, 12), datetime.datetime(2021, 1, 1, 0, 39, 46), 18.95, 'Manhattan/Yorkville West', '/'),
#  (datetime.datetime(2021, 1, 1, 0, 15, 52), datetime.datetime(2021, 1, 1, 0, 38, 7), 24.3, 'Manhattan/Midtown South', 'Brooklyn/Williamsburg (North Side)')]

# %%
# %%sql
# SELECT COUNT(1) FROM (
#     SELECT
#         tpep_pickup_datetime,
#         tpep_dropoff_datetime,
#         total_amount,
#         CONCAT(zpu."Borough", '/', zpu."Zone") AS "pickup_loc",
#         CONCAT(zdo."Borough", '/', zdo."Zone") AS "dropoff_loc"
#     FROM
#         yellow_taxi_trips yt JOIN taxi_zones zpu
#             ON yt."PULocationID" = zpu."LocationID"
#         LEFT JOIN taxi_zones zdo
#             ON yt."DOLocationID" = zdo."LocationID"
#     ) AS subtable;
# Out:
#  * postgresql://root:***@localhost:5432/ny_taxi
# 1 rows affected.
# [(1327650,)]

# %% [markdown]
# * ***Left joins*** shows all rows from the "left" part of the statement but only the rows from the "right" part that overlap with the "left" part, thus the name.
# * This join is useful if we deleted one of the `LocationID` rows like before. The inner join would omit some rows from the `trips` table, but this query will show all rows. However, since one ID is missing, the "virtual" columns we defined to transform location ID's to actual names will appear with empty strings if the query cannot find the location ID.

# %%
# %%sql
# SELECT
#     tpep_pickup_datetime,
#     tpep_dropoff_datetime,
#     total_amount,
#     CONCAT(zpu."Borough", '/', zpu."Zone") AS "pickup_loc",
#     CONCAT(zdo."Borough", '/', zdo."Zone") AS "dropoff_loc"
# FROM
#     yellow_taxi_trips yt LEFT JOIN taxi_zones zpu
#         ON yt."PULocationID" = zpu."LocationID"
#     LEFT JOIN taxi_zones zdo
#         ON yt."DOLocationID" = zdo."LocationID"
# LIMIT 10;
# Out:
#  * postgresql://root:***@localhost:5432/ny_taxi
# 10 rows affected.
# [(datetime.datetime(2021, 1, 1, 0, 30, 10), datetime.datetime(2021, 1, 1, 0, 36, 12), 11.8, '/', 'Manhattan/Central Park'),
#  (datetime.datetime(2021, 1, 1, 0, 51, 20), datetime.datetime(2021, 1, 1, 0, 52, 19), 4.3, 'Manhattan/Upper West Side North', 'Manhattan/Manhattan Valley'),
#  (datetime.datetime(2021, 1, 1, 0, 43, 30), datetime.datetime(2021, 1, 1, 1, 11, 6), 51.95, 'Queens/JFK Airport', 'Brooklyn/Midwood'),
#  (datetime.datetime(2021, 1, 1, 0, 15, 48), datetime.datetime(2021, 1, 1, 0, 31, 1), 36.35, 'Queens/LaGuardia Airport', 'Queens/JFK Airport'),
#  (datetime.datetime(2021, 1, 1, 0, 31, 49), datetime.datetime(2021, 1, 1, 0, 48, 21), 24.36, 'Manhattan/East Chelsea', 'Brooklyn/Brooklyn Heights'),
#  (datetime.datetime(2021, 1, 1, 0, 16, 29), datetime.datetime(2021, 1, 1, 0, 24, 30), 14.15, 'Manhattan/Stuy Town/Peter Cooper Village', 'Manhattan/East Chelsea'),
#  (datetime.datetime(2021, 1, 1, 0, 0, 28), datetime.datetime(2021, 1, 1, 0, 17, 28), 17.3, 'Queens/Forest Hills', 'Queens/Maspeth'),
#  (datetime.datetime(2021, 1, 1, 0, 12, 29), datetime.datetime(2021, 1, 1, 0, 30, 34), 21.8, 'Manhattan/Flatiron', 'Brooklyn/Carroll Gardens'),
#  (datetime.datetime(2021, 1, 1, 0, 39, 16), datetime.datetime(2021, 1, 1, 1, 0, 13), 28.8, 'Brooklyn/Fort Greene', 'Queens/Jackson Heights'),
#  (datetime.datetime(2021, 1, 1, 0, 26, 12), datetime.datetime(2021, 1, 1, 0, 39, 46), 18.95, 'Manhattan/Yorkville West', '/')]

# %%
# %%sql
# SELECT COUNT(1) FROM (
#     SELECT
#         tpep_pickup_datetime,
#         tpep_dropoff_datetime,
#         total_amount,
#         CONCAT(zpu."Borough", '/', zpu."Zone") AS "pickup_loc",
#         CONCAT(zdo."Borough", '/', zdo."Zone") AS "dropoff_loc"
#     FROM
#         yellow_taxi_trips yt LEFT JOIN taxi_zones zpu
#             ON yt."PULocationID" = zpu."LocationID"
#         LEFT JOIN taxi_zones zdo
#             ON yt."DOLocationID" = zdo."LocationID"
#     ) AS subtable;
# Out:
#  * postgresql://root:***@localhost:5432/ny_taxi
# 1 rows affected.
# [(1369765,)]

# %% [markdown]
# ### Comparing the count result by using simple `JOIN` and `LEFT JOIN` we can see the number of rows returned on left join is more.
# Thus returning all the rows from the `yellow_taxi_zones` table.

# %% [markdown]
# * `DATE_TRUNC` is a function that trunctates a timestamp. When using `DAY` as a parameter, it removes any smaller values (hours, minutes, seconds) and displays them as `00:00:00` instead.
# * `CAST` function will display the datas as simple dates removing the item `00:00:00`

# %%
# %%sql
# SELECT
#     tpep_pickup_datetime,
#     tpep_dropoff_datetime,
#     DATE_TRUNC('DAY', tpep_dropoff_datetime),
#     total_amount
# FROM
#     yellow_taxi_trips
# LIMIT 10;
# Out:
#  * postgresql://root:***@localhost:5432/ny_taxi
# 10 rows affected.
# [(datetime.datetime(2021, 1, 1, 0, 30, 10), datetime.datetime(2021, 1, 1, 0, 36, 12), datetime.datetime(2021, 1, 1, 0, 0), 11.8),
#  (datetime.datetime(2021, 1, 1, 0, 51, 20), datetime.datetime(2021, 1, 1, 0, 52, 19), datetime.datetime(2021, 1, 1, 0, 0), 4.3),
#  (datetime.datetime(2021, 1, 1, 0, 43, 30), datetime.datetime(2021, 1, 1, 1, 11, 6), datetime.datetime(2021, 1, 1, 0, 0), 51.95),
#  (datetime.datetime(2021, 1, 1, 0, 15, 48), datetime.datetime(2021, 1, 1, 0, 31, 1), datetime.datetime(2021, 1, 1, 0, 0), 36.35),
#  (datetime.datetime(2021, 1, 1, 0, 31, 49), datetime.datetime(2021, 1, 1, 0, 48, 21), datetime.datetime(2021, 1, 1, 0, 0), 24.36),
#  (datetime.datetime(2021, 1, 1, 0, 16, 29), datetime.datetime(2021, 1, 1, 0, 24, 30), datetime.datetime(2021, 1, 1, 0, 0), 14.15),
#  (datetime.datetime(2021, 1, 1, 0, 0, 28), datetime.datetime(2021, 1, 1, 0, 17, 28), datetime.datetime(2021, 1, 1, 0, 0), 17.3),
#  (datetime.datetime(2021, 1, 1, 0, 12, 29), datetime.datetime(2021, 1, 1, 0, 30, 34), datetime.datetime(2021, 1, 1, 0, 0), 21.8),
#  (datetime.datetime(2021, 1, 1, 0, 39, 16), datetime.datetime(2021, 1, 1, 1, 0, 13), datetime.datetime(2021, 1, 1, 0, 0), 28.8),
#  (datetime.datetime(2021, 1, 1, 0, 26, 12), datetime.datetime(2021, 1, 1, 0, 39, 46), datetime.datetime(2021, 1, 1, 0, 0), 18.95)]

# %%
# %%sql
# SELECT
#     tpep_pickup_datetime,
#     tpep_dropoff_datetime,
#     CAST(tpep_dropoff_datetime AS DATE),
#     total_amount
# FROM
#     yellow_taxi_trips
# LIMIT 10;
# Out:
#  * postgresql://root:***@localhost:5432/ny_taxi
# 10 rows affected.
# [(datetime.datetime(2021, 1, 1, 0, 30, 10), datetime.datetime(2021, 1, 1, 0, 36, 12), datetime.date(2021, 1, 1), 11.8),
#  (datetime.datetime(2021, 1, 1, 0, 51, 20), datetime.datetime(2021, 1, 1, 0, 52, 19), datetime.date(2021, 1, 1), 4.3),
#  (datetime.datetime(2021, 1, 1, 0, 43, 30), datetime.datetime(2021, 1, 1, 1, 11, 6), datetime.date(2021, 1, 1), 51.95),
#  (datetime.datetime(2021, 1, 1, 0, 15, 48), datetime.datetime(2021, 1, 1, 0, 31, 1), datetime.date(2021, 1, 1), 36.35),
#  (datetime.datetime(2021, 1, 1, 0, 31, 49), datetime.datetime(2021, 1, 1, 0, 48, 21), datetime.date(2021, 1, 1), 24.36),
#  (datetime.datetime(2021, 1, 1, 0, 16, 29), datetime.datetime(2021, 1, 1, 0, 24, 30), datetime.date(2021, 1, 1), 14.15),
#  (datetime.datetime(2021, 1, 1, 0, 0, 28), datetime.datetime(2021, 1, 1, 0, 17, 28), datetime.date(2021, 1, 1), 17.3),
#  (datetime.datetime(2021, 1, 1, 0, 12, 29), datetime.datetime(2021, 1, 1, 0, 30, 34), datetime.date(2021, 1, 1), 21.8),
#  (datetime.datetime(2021, 1, 1, 0, 39, 16), datetime.datetime(2021, 1, 1, 1, 0, 13), datetime.date(2021, 1, 1), 28.8),
#  (datetime.datetime(2021, 1, 1, 0, 26, 12), datetime.datetime(2021, 1, 1, 0, 39, 46), datetime.date(2021, 1, 1), 18.95)]

# %%
# %%sql
# SELECT
#     CAST(tpep_dropoff_datetime AS DATE) AS "day",
#     COUNT(1)
# FROM
#     yellow_taxi_trips
# GROUP BY
#     CAST(tpep_dropoff_datetime AS DATE)
# ORDER BY day ASC;
# Out:
#  * postgresql://root:***@localhost:5432/ny_taxi
# 37 rows affected.
# [(datetime.date(2008, 12, 31), 1),
#  (datetime.date(2009, 1, 1), 3),
#  (datetime.date(2020, 10, 13), 1),
#  (datetime.date(2020, 12, 31), 9),
#  (datetime.date(2021, 1, 1), 24672),
#  (datetime.date(2021, 1, 2), 34230),
#  (datetime.date(2021, 1, 3), 26374),
#  (datetime.date(2021, 1, 4), 44588),
#  (datetime.date(2021, 1, 5), 46882),
#  (datetime.date(2021, 1, 6), 49549),
#  (datetime.date(2021, 1, 7), 50245),
#  (datetime.date(2021, 1, 8), 50467),
#  (datetime.date(2021, 1, 9), 39935),
#  (datetime.date(2021, 1, 10), 29873),
#  (datetime.date(2021, 1, 11), 46875),
#  (datetime.date(2021, 1, 12), 50115),
#  (datetime.date(2021, 1, 13), 51294),
#  (datetime.date(2021, 1, 14), 53019),
#  (datetime.date(2021, 1, 15), 52977),
#  (datetime.date(2021, 1, 16), 38767),
#  (datetime.date(2021, 1, 17), 32022),
#  (datetime.date(2021, 1, 18), 37127),
#  (datetime.date(2021, 1, 19), 51120),
#  (datetime.date(2021, 1, 20), 49447),
#  (datetime.date(2021, 1, 21), 53246),
#  (datetime.date(2021, 1, 22), 54225),
#  (datetime.date(2021, 1, 23), 42088),
#  (datetime.date(2021, 1, 24), 31093),
#  (datetime.date(2021, 1, 25), 47409),
#  (datetime.date(2021, 1, 26), 47821),
#  (datetime.date(2021, 1, 27), 52676),
#  (datetime.date(2021, 1, 28), 56385),
#  (datetime.date(2021, 1, 29), 54601),
#  (datetime.date(2021, 1, 30), 39228),
#  (datetime.date(2021, 1, 31), 31278),
#  (datetime.date(2021, 2, 1), 122),
#  (datetime.date(2021, 2, 22), 1)]

# %% [markdown]
# ### Storing the output as dataframe for futher analyzing in pandas.

# %%
import pandas as pd
from sqlalchemy import create_engine

# Replace with your database connection details
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# Execute the SQL query and store the results as a DataFrame
df = pd.read_sql_query("""
    SELECT 
        CAST(tpep_dropoff_datetime AS DATE) AS "day",
        COUNT(1)
    FROM
        yellow_taxi_trips
    GROUP BY
        CAST(tpep_dropoff_datetime AS DATE)
""", engine)

# Print the DataFrame to verify the results
df.head()
# Out:
#           day  count
# 0  2021-01-21  53246
# 1  2009-01-01      3
# 2  2021-01-09  39935
# 3  2021-01-11  46875
# 4  2021-01-29  54601

# %%
# %%sql
# SELECT
#     CAST(tpep_dropoff_datetime AS DATE) AS "day",
#     COUNT(1) as count
# FROM
#     yellow_taxi_trips
# GROUP BY
#     CAST(tpep_dropoff_datetime AS DATE)
# ORDER BY count DESC
# LIMIT 5;
# Out:
#  * postgresql://root:***@localhost:5432/ny_taxi
# 5 rows affected.
# [(datetime.date(2021, 1, 28), 56385),
#  (datetime.date(2021, 1, 29), 54601),
#  (datetime.date(2021, 1, 22), 54225),
#  (datetime.date(2021, 1, 21), 53246),
#  (datetime.date(2021, 1, 14), 53019)]

# %%
# %%sql
# SELECT
#     CAST(tpep_dropoff_datetime AS DATE) AS "day",
#     COUNT(1) as count,
#     MAX(total_amount) AS max_amount,
#     MAX(passenger_count) AS max_no_of_passengers
# FROM
#     yellow_taxi_trips
# GROUP BY
#     CAST(tpep_dropoff_datetime AS DATE)
# ORDER BY 3 DESC
# LIMIT 10;
# Out:
#  * postgresql://root:***@localhost:5432/ny_taxi
# 10 rows affected.
# [(datetime.date(2021, 1, 4), 44588, 7661.28, 6),
#  (datetime.date(2021, 1, 20), 49447, 2292.4, 6),
#  (datetime.date(2021, 1, 12), 50115, 1155.65, 7),
#  (datetime.date(2021, 1, 3), 26374, 1108.2, 6),
#  (datetime.date(2021, 1, 10), 29873, 900.35, 6),
#  (datetime.date(2021, 1, 19), 51120, 894.2, 7),
#  (datetime.date(2021, 1, 6), 49549, 872.54, 6),
#  (datetime.date(2021, 1, 7), 50245, 872.05, 6),
#  (datetime.date(2021, 1, 27), 52676, 831.0, 6),
#  (datetime.date(2021, 1, 8), 50467, 815.05, 6)]

# %%
# %%sql
# SELECT
#     CAST(tpep_dropoff_datetime AS DATE) AS "day",
#     "DOLocationID",
#     COUNT(1) as count,
#     MAX(total_amount) AS max_amount,
#     MAX(passenger_count) AS max_no_of_passengers
# FROM
#     yellow_taxi_trips
# GROUP BY
#     1, 2
# ORDER BY
#     1 ASC, 2 ASC
# LIMIT 10;
# Out:
#  * postgresql://root:***@localhost:5432/ny_taxi
# 10 rows affected.
# [(datetime.date(2008, 12, 31), 193, 1, 0.0, 1),
#  (datetime.date(2009, 1, 1), 10, 1, 14.3, 1),
#  (datetime.date(2009, 1, 1), 89, 1, 10.3, 1),
#  (datetime.date(2009, 1, 1), 238, 1, 11.8, 6),
#  (datetime.date(2020, 10, 13), 234, 1, 13.3, 1),
#  (datetime.date(2020, 12, 31), 68, 1, 14.3, 1),
#  (datetime.date(2020, 12, 31), 74, 2, 12.8, 1),
#  (datetime.date(2020, 12, 31), 79, 1, 14.12, 1),
#  (datetime.date(2020, 12, 31), 137, 1, 24.8, 1),
#  (datetime.date(2020, 12, 31), 213, 1, 53.3, 1)]
